# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import vis.classification_vis as cvis
from Evals import *
from Data_Provider import *
import util.classification_utils as util
import util.data_utils as dutil
import util.label_utils as lutil


import numpy as np
from scipy import interp
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
import os

from itertools import product
from multiprocessing import Pool
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/emil/miniconda3/envs/emocog/lib/python3.7/site-packages/hypertools/plot/__init__.py:10: UserWarning: Could not switch backend to TkAgg.  This may impact performance of the plotting functions.
#   warnings.warn('Could not switch backend to TkAgg.  This may impact performance of the plotting functions.')
# /home/emil/miniconda3/envs/emocog/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
def train_and_save_best_classifier(results,x,y,configs):
    best_n, best_d, best_f = util.get_best_hyperparas(results,'AVG PR')
    classifier = RandomForestClassifier(n_estimators=int(best_n), max_depth=int(best_d), max_features=int(best_f),random_state=0) #init classifier
    classifier.fit(x,y)
    best_thr = util.get_optimal_threshold(classifier, x, y, go_after_pr=True) # get threshold using cv (on whole dataset)
    dutil.save_classifier(classifier, best_thr, configs,'RF')
    
    

# Run classifier with cross-validation
def calc_results_and_save(x, y, configs, shuff):
    cv = StratifiedKFold(n_splits=10, shuffle=shuff, random_state=1)
    #dataframe for saving results
    results = pd.DataFrame(columns=('Number Estimators','Max Depth','Max Features','AVG PR'))#,'AUC ROC'))
    #do random search on parameters
    est = np.random.choice(np.arange(130)[5:],50)
    max_d = np.random.choice(np.arange(60)[1:],50)
    max_f = np.random.choice(np.arange(min(x.shape))[1:],50)

    #Search for best hyperpara combo with cross validation
    for idx,(c,d,f) in enumerate(zip(est,max_d,max_f)):
        classifier = RandomForestClassifier(n_estimators=c, max_depth=d, max_features=f,random_state=0) #init classifier
        auc_pr = util.get_auc_score(classifier, cv, x, y, go_after_pr=True)
        #auc_roc =util.get_auc_score(classifier, cv, x, y, go_after_pr=False)
        results.loc[idx] = [c,d,f,auc_pr]
        print('Number Estimators= %d, Max Depth = %d, Max Feat = %d, AUC PR %.3f' % (c,d,f,auc_pr))
    if shuff:
        dutil.save_results(results,configs,'RF_Shuffle') # save results for later use
    else:
        dutil.save_results(results,configs,'RF') # save results for later use      
    return results


def vis_results(x,y, x_ev, y_ev, configs):
    ###using hyperpara found, evaluate and get pretty plots
    #get f1 scores on whole training set
    classifier, best_thr = dutil.load_classifier(configs,'RF')
    y_pred = util.get_prediction(classifier,x,best_thr)
    y_pred_ev = util.get_prediction(classifier,x_ev,best_thr)
    f1_tr=get_f1(y_pred,y) # calculate f1 scores for prediction on train set
    f1_ev=get_f1(y_pred_ev,y_ev)
    prec_tr,recall_tr = get_precision_recall(y_pred,y)
    prec_ev,recall_ev = get_precision_recall(y_pred_ev,y_ev)

    df_res = pd.DataFrame(index =['Train','Eval'],columns = ['Precision','Recall','F1']).astype('float')
    df_res.loc['Train'] = [prec_tr, recall_tr,f1_tr]
    df_res.loc['Eval'] = [prec_ev, recall_ev,f1_ev]
    cvis.print_results(df_res)
    #draw pretty plots
    cvis.conf_mat(y_pred,y)
    cvis.conf_mat(y_pred_ev,y_ev)

    cvis.plot_roc(x,y,classifier, 'Random Forest ROC on Train Set')
    cvis.plot_roc(x_ev,y_ev,classifier,  'Random Forest ROC on Eval Set')
    cvis.plot_pr_curve(x,y,classifier, 'Random Forest Pr-Re curve on Train Set')
    cvis.plot_pr_curve(x_ev,y_ev,classifier, 'Random Forest ROC on Eval Set')

    
def do_all(file, cut, shuffled=False, random = False, reload= False):
# def do_all(data, cut, shuffled=False, random = True):
    provider = DataProvider()
    configs = dutil.generate_configs_from_file(file, cut)
    print(configs)
    x,y,x_ev,y_ev = provider.get_data(configs)
    print(x.shape,y.shape,x_ev.shape,y_ev.shape)
    #if random:
    if False:
        print('yes, random')
        np.random.seed()
        y = randomize_labels(y)
        y_ev = randomize_labels(y_ev)
    if reload:
        res = dutil.load_results(configs,'RF')
    else:
        res = calc_results_and_save(x,y,configs,shuffled)
    
    train_and_save_best_classifier(res,x,y,configs)

    res = calc_results_and_save(x,y,shuffled)
#     #### get best resul on train set
#     pos = res['AVG PR'].idxmax()
#     best_row=list(res.loc[pos].values) # get the row with highest ev score
#     best_row.append(y)
#     best_row.append(y_ev)
#     return best_row
    ####
    vis_results(x,y, x_ev, y_ev, configs)
    
def randomize_labels(y):
    ones = int(np.sum(y))
    #where?
    fill_ones = np.random.choice(len(y),ones, replace=False)
    ret = np.empty(len(y))
    ret[:]=0
    ret[fill_ones]=1
    return ret

# %%
files = [f for f in os.listdir('/home/emil/OpenMindv2/data/postprocessing') if 'shuffle_True' in f and '3' in f]
cuts = [.05,.1,.2,.3]
# shuffled =[False]
all_elements = [files,cuts]
# #all_elements = [[bla],cuts]

file_cut_combos = []
for allel in product(*all_elements):
    file_cut_combos+=[allel]

# %%
files
# Out:
# ['patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_5_sliding_False_expvar_90_ratio_0.8_shuffle_True',
#  'patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_100_sliding_False_expvar_90_ratio_0.8_shuffle_True',
#  'patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_50_sliding_False_expvar_90_ratio_0.8_shuffle_True']

# %%
# do_all(files[2],.1)

pool = mp.Pool(7)
yass = pool.starmap(do_all,file_cut_combos)

del(pool)
del(yass)
# Out:
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 5, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.05}
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 5, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.1}
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 5, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.2}
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 100, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.1}
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 100, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.2}
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 5, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.3}
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_5_sliding_False_expvar_90_ratio_0.8_shuffle_True
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_5_sliding_False_expvar_90_ratio_0.8_shuffle_True
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 100, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.05}
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_100_sliding_False_expvar_90_ratio_0.8_shuffle_True
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_100_sliding_False_expvar_90_ratio_0.8_shuffle_True
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_5_sliding_False_expvar_90_ratio_0.8_shuffle_True
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_100_sliding_False_expvar_90_ratio_0.8_shuffle_True
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_5_sliding_False_expvar_90_ratio_0.8_shuffle_True
# Loading Data from File..done
# Loading Data from File..done
# Loading Data from File..done
# Doing cutoff
# Doing cutoff
# Doing cutoff
# (1101, 23) (1101,) (283, 23) (283,)
# (1101, 23) (1101,) (283, 23) (283,)
# (1101, 23) (1101,) (283, 23) (283,)
# Loading Data from File..done
# Doing cutoff
# (18639, 92) (18639,) (4641, 92) (4641,)
# Loading Data from File..done
# Loading Data from File..done
# Doing cutoff
# Doing cutoff
# (18639, 92) (18639,) (4641, 92) (4641,)
# (18639, 92) (18639,) (4641, 92) (4641,)
# Loading Data from File..done
# Doing cutoff
# (18639, 92) (18639,) (4641, 92) (4641,)
# Number Estimators= 77, Max Depth = 56, Max Feat = 12, AUC PR 0.537
# Number Estimators= 77, Max Depth = 56, Max Feat = 12, AUC PR 0.298
# Number Estimators= 77, Max Depth = 56, Max Feat = 12, AUC PR 0.400
# Number Estimators= 77, Max Depth = 44, Max Feat = 15, AUC PR 0.286
# Number Estimators= 77, Max Depth = 44, Max Feat = 15, AUC PR 0.529
# Number Estimators= 77, Max Depth = 44, Max Feat = 15, AUC PR 0.419
# Number Estimators= 87, Max Depth = 14, Max Feat = 13, AUC PR 0.538
# Number Estimators= 87, Max Depth = 14, Max Feat = 13, AUC PR 0.394
# Number Estimators= 87, Max Depth = 14, Max Feat = 13, AUC PR 0.311
# Number Estimators= 121, Max Depth = 7, Max Feat = 6, AUC PR 0.549
# Number Estimators= 121, Max Depth = 7, Max Feat = 6, AUC PR 0.438
# Number Estimators= 121, Max Depth = 7, Max Feat = 6, AUC PR 0.372
# Number Estimators= 93, Max Depth = 31, Max Feat = 13, AUC PR 0.394
# Number Estimators= 93, Max Depth = 31, Max Feat = 13, AUC PR 0.555
# Number Estimators= 93, Max Depth = 31, Max Feat = 13, AUC PR 0.305
# Number Estimators= 87, Max Depth = 52, Max Feat = 2, AUC PR 0.389
# Number Estimators= 87, Max Depth = 52, Max Feat = 2, AUC PR 0.550
# Number Estimators= 87, Max Depth = 52, Max Feat = 2, AUC PR 0.280
# Number Estimators= 126, Max Depth = 16, Max Feat = 11, AUC PR 0.395
# Number Estimators= 126, Max Depth = 16, Max Feat = 11, AUC PR 0.549
# Number Estimators= 126, Max Depth = 16, Max Feat = 11, AUC PR 0.281
# Number Estimators= 40, Max Depth = 23, Max Feat = 14, AUC PR 0.429
# Number Estimators= 40, Max Depth = 23, Max Feat = 14, AUC PR 0.556
# Number Estimators= 40, Max Depth = 23, Max Feat = 14, AUC PR 0.286
# Number Estimators= 117, Max Depth = 52, Max Feat = 2, AUC PR 0.385
# Number Estimators= 117, Max Depth = 52, Max Feat = 2, AUC PR 0.544
# Number Estimators= 117, Max Depth = 52, Max Feat = 2, AUC PR 0.288
# Number Estimators= 41, Max Depth = 54, Max Feat = 12, AUC PR 0.553
# Number Estimators= 41, Max Depth = 54, Max Feat = 12, AUC PR 0.419
# Number Estimators= 41, Max Depth = 54, Max Feat = 12, AUC PR 0.298
# Number Estimators= 95, Max Depth = 31, Max Feat = 5, AUC PR 0.531
# Number Estimators= 95, Max Depth = 31, Max Feat = 5, AUC PR 0.398
# Number Estimators= 95, Max Depth = 31, Max Feat = 5, AUC PR 0.295
# Number Estimators= 109, Max Depth = 51, Max Feat = 9, AUC PR 0.390
# Number Estimators= 109, Max Depth = 51, Max Feat = 9, AUC PR 0.556
# Number Estimators= 109, Max Depth = 51, Max Feat = 9, AUC PR 0.280
# Number Estimators= 84, Max Depth = 38, Max Feat = 6, AUC PR 0.402
# Number Estimators= 84, Max Depth = 38, Max Feat = 6, AUC PR 0.529
# Number Estimators= 22, Max Depth = 48, Max Feat = 4, AUC PR 0.397
# Number Estimators= 22, Max Depth = 48, Max Feat = 4, AUC PR 0.539
# Number Estimators= 84, Max Depth = 38, Max Feat = 6, AUC PR 0.275
# Number Estimators= 22, Max Depth = 48, Max Feat = 4, AUC PR 0.289
# Number Estimators= 41, Max Depth = 23, Max Feat = 15, AUC PR 0.423
# Number Estimators= 41, Max Depth = 23, Max Feat = 15, AUC PR 0.530
# Number Estimators= 11, Max Depth = 31, Max Feat = 2, AUC PR 0.392
# Number Estimators= 11, Max Depth = 31, Max Feat = 2, AUC PR 0.575
# Number Estimators= 41, Max Depth = 23, Max Feat = 15, AUC PR 0.275
# Number Estimators= 11, Max Depth = 31, Max Feat = 2, AUC PR 0.296
# Number Estimators= 117, Max Depth = 20, Max Feat = 15, AUC PR 0.396
# Number Estimators= 117, Max Depth = 20, Max Feat = 15, AUC PR 0.539
# Number Estimators= 117, Max Depth = 20, Max Feat = 15, AUC PR 0.282
# Number Estimators= 72, Max Depth = 34, Max Feat = 22, AUC PR 0.402
# Number Estimators= 72, Max Depth = 34, Max Feat = 22, AUC PR 0.564
# Number Estimators= 72, Max Depth = 34, Max Feat = 22, AUC PR 0.279
# Number Estimators= 68, Max Depth = 59, Max Feat = 15, AUC PR 0.408
# Number Estimators= 68, Max Depth = 59, Max Feat = 15, AUC PR 0.532
# Number Estimators= 68, Max Depth = 59, Max Feat = 15, AUC PR 0.279
# Number Estimators= 99, Max Depth = 11, Max Feat = 14, AUC PR 0.390
# Number Estimators= 99, Max Depth = 11, Max Feat = 14, AUC PR 0.556
# Number Estimators= 99, Max Depth = 11, Max Feat = 14, AUC PR 0.282
# Number Estimators= 74, Max Depth = 21, Max Feat = 9, AUC PR 0.395
# Number Estimators= 74, Max Depth = 21, Max Feat = 9, AUC PR 0.554
# Number Estimators= 74, Max Depth = 21, Max Feat = 9, AUC PR 0.273
# Number Estimators= 60, Max Depth = 23, Max Feat = 10, AUC PR 0.404
# Number Estimators= 60, Max Depth = 23, Max Feat = 10, AUC PR 0.553
# Number Estimators= 60, Max Depth = 23, Max Feat = 10, AUC PR 0.275
# Number Estimators= 85, Max Depth = 10, Max Feat = 8, AUC PR 0.412
# Number Estimators= 85, Max Depth = 10, Max Feat = 8, AUC PR 0.531
# Number Estimators= 85, Max Depth = 10, Max Feat = 8, AUC PR 0.275
# Number Estimators= 125, Max Depth = 35, Max Feat = 3, AUC PR 0.412
# Number Estimators= 125, Max Depth = 35, Max Feat = 3, AUC PR 0.556
# Number Estimators= 125, Max Depth = 35, Max Feat = 3, AUC PR 0.279
# Number Estimators= 54, Max Depth = 33, Max Feat = 7, AUC PR 0.383
# Number Estimators= 54, Max Depth = 33, Max Feat = 7, AUC PR 0.527
# Number Estimators= 55, Max Depth = 52, Max Feat = 3, AUC PR 0.409
# Number Estimators= 54, Max Depth = 33, Max Feat = 7, AUC PR 0.274
# Number Estimators= 55, Max Depth = 52, Max Feat = 3, AUC PR 0.566
# Number Estimators= 55, Max Depth = 52, Max Feat = 3, AUC PR 0.296
# Number Estimators= 76, Max Depth = 26, Max Feat = 16, AUC PR 0.391
# Number Estimators= 76, Max Depth = 26, Max Feat = 16, AUC PR 0.548
# Number Estimators= 112, Max Depth = 1, Max Feat = 9, AUC PR 0.603
# Number Estimators= 76, Max Depth = 26, Max Feat = 16, AUC PR 0.290
# Number Estimators= 112, Max Depth = 1, Max Feat = 9, AUC PR 0.692
# Number Estimators= 112, Max Depth = 1, Max Feat = 9, AUC PR 0.523
# Number Estimators= 118, Max Depth = 29, Max Feat = 10, AUC PR 0.398
# Number Estimators= 118, Max Depth = 29, Max Feat = 10, AUC PR 0.545
# Number Estimators= 118, Max Depth = 29, Max Feat = 10, AUC PR 0.275
# Number Estimators= 122, Max Depth = 2, Max Feat = 13, AUC PR 0.530
# Number Estimators= 122, Max Depth = 2, Max Feat = 13, AUC PR 0.616
# Number Estimators= 23, Max Depth = 39, Max Feat = 6, AUC PR 0.425
# Number Estimators= 23, Max Depth = 39, Max Feat = 6, AUC PR 0.532
# Number Estimators= 122, Max Depth = 2, Max Feat = 13, AUC PR 0.517
# Number Estimators= 23, Max Depth = 39, Max Feat = 6, AUC PR 0.271
# Number Estimators= 33, Max Depth = 54, Max Feat = 13, AUC PR 0.403
# Number Estimators= 33, Max Depth = 54, Max Feat = 13, AUC PR 0.556
# Number Estimators= 39, Max Depth = 2, Max Feat = 19, AUC PR 0.509
# Number Estimators= 33, Max Depth = 54, Max Feat = 13, AUC PR 0.285
# Number Estimators= 39, Max Depth = 2, Max Feat = 19, AUC PR 0.631
# Number Estimators= 31, Max Depth = 35, Max Feat = 9, AUC PR 0.391
# Number Estimators= 39, Max Depth = 2, Max Feat = 19, AUC PR 0.538
# Number Estimators= 31, Max Depth = 31, Max Feat = 3, AUC PR 0.420
# Number Estimators= 31, Max Depth = 35, Max Feat = 9, AUC PR 0.554
# Number Estimators= 31, Max Depth = 31, Max Feat = 3, AUC PR 0.560
# Number Estimators= 31, Max Depth = 35, Max Feat = 9, AUC PR 0.281
# Number Estimators= 115, Max Depth = 2, Max Feat = 8, AUC PR 0.525
# Number Estimators= 31, Max Depth = 31, Max Feat = 3, AUC PR 0.306
# Number Estimators= 115, Max Depth = 2, Max Feat = 8, AUC PR 0.622
# Number Estimators= 54, Max Depth = 22, Max Feat = 4, AUC PR 0.386
# Number Estimators= 115, Max Depth = 2, Max Feat = 8, AUC PR 0.494
# Number Estimators= 54, Max Depth = 22, Max Feat = 4, AUC PR 0.525
# Number Estimators= 54, Max Depth = 22, Max Feat = 4, AUC PR 0.286
# Number Estimators= 81, Max Depth = 2, Max Feat = 18, AUC PR 0.545
# Number Estimators= 81, Max Depth = 2, Max Feat = 18, AUC PR 0.636
# Number Estimators= 37, Max Depth = 26, Max Feat = 7, AUC PR 0.384
# Number Estimators= 81, Max Depth = 2, Max Feat = 18, AUC PR 0.515
# Number Estimators= 37, Max Depth = 26, Max Feat = 7, AUC PR 0.527
# Number Estimators= 105, Max Depth = 17, Max Feat = 2, AUC PR 0.386
# Number Estimators= 37, Max Depth = 26, Max Feat = 7, AUC PR 0.275
# Number Estimators= 10, Max Depth = 44, Max Feat = 12, AUC PR 0.414
# Number Estimators= 105, Max Depth = 17, Max Feat = 2, AUC PR 0.558
# Number Estimators= 8, Max Depth = 50, Max Feat = 15, AUC PR 0.442
# Number Estimators= 10, Max Depth = 44, Max Feat = 12, AUC PR 0.584
# Number Estimators= 105, Max Depth = 17, Max Feat = 2, AUC PR 0.296
# Number Estimators= 8, Max Depth = 50, Max Feat = 15, AUC PR 0.564
# Number Estimators= 10, Max Depth = 44, Max Feat = 12, AUC PR 0.308
# Number Estimators= 8, Max Depth = 50, Max Feat = 15, AUC PR 0.299
# Number Estimators= 74, Max Depth = 35, Max Feat = 5, AUC PR 0.402
# Number Estimators= 74, Max Depth = 35, Max Feat = 5, AUC PR 0.533
# Number Estimators= 74, Max Depth = 35, Max Feat = 5, AUC PR 0.288
# Number Estimators= 81, Max Depth = 50, Max Feat = 6, AUC PR 0.400
# Number Estimators= 81, Max Depth = 50, Max Feat = 6, AUC PR 0.533
# Number Estimators= 40, Max Depth = 46, Max Feat = 6, AUC PR 0.402
# Number Estimators= 81, Max Depth = 50, Max Feat = 6, AUC PR 0.275
# Number Estimators= 40, Max Depth = 46, Max Feat = 6, AUC PR 0.529
# Number Estimators= 30, Max Depth = 5, Max Feat = 16, AUC PR 0.465
# Number Estimators= 40, Max Depth = 46, Max Feat = 6, AUC PR 0.271
# Number Estimators= 30, Max Depth = 5, Max Feat = 16, AUC PR 0.559
# Number Estimators= 30, Max Depth = 5, Max Feat = 16, AUC PR 0.342
# Number Estimators= 84, Max Depth = 49, Max Feat = 14, AUC PR 0.411
# Number Estimators= 84, Max Depth = 49, Max Feat = 14, AUC PR 0.558
# Number Estimators= 84, Max Depth = 49, Max Feat = 14, AUC PR 0.287
# Number Estimators= 102, Max Depth = 34, Max Feat = 12, AUC PR 0.400
# Number Estimators= 102, Max Depth = 34, Max Feat = 12, AUC PR 0.542
# Number Estimators= 102, Max Depth = 34, Max Feat = 12, AUC PR 0.288
# Number Estimators= 71, Max Depth = 7, Max Feat = 11, AUC PR 0.419
# Number Estimators= 71, Max Depth = 7, Max Feat = 11, AUC PR 0.553
# Number Estimators= 71, Max Depth = 7, Max Feat = 11, AUC PR 0.305
# Number Estimators= 81, Max Depth = 23, Max Feat = 20, AUC PR 0.380
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 100, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.3}
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_100_sliding_False_expvar_90_ratio_0.8_shuffle_True
# Loading Data from File..done
# Doing cutoff
# (1101, 23) (1101,) (283, 23) (283,)
# Number Estimators= 81, Max Depth = 23, Max Feat = 20, AUC PR 0.548
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 50, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.05}
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_50_sliding_False_expvar_90_ratio_0.8_shuffle_True
# Loading Data from File..done
# Doing cutoff
# (2087, 29) (2087,) (521, 29) (521,)
# Number Estimators= 75, Max Depth = 37, Max Feat = 1, AUC PR 0.182
# Number Estimators= 8, Max Depth = 6, Max Feat = 14, AUC PR 0.229
# Number Estimators= 81, Max Depth = 23, Max Feat = 20, AUC PR 0.280
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 50, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.1}
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_50_sliding_False_expvar_90_ratio_0.8_shuffle_True
# Loading Data from File..done
# Doing cutoff
# (2087, 29) (2087,) (521, 29) (521,)
# Number Estimators= 75, Max Depth = 37, Max Feat = 1, AUC PR 0.445
# Number Estimators= 100, Max Depth = 36, Max Feat = 1, AUC PR 0.178
# Number Estimators= 8, Max Depth = 6, Max Feat = 14, AUC PR 0.472
# Number Estimators= 75, Max Depth = 37, Max Feat = 1, AUC PR 0.353
# Number Estimators= 8, Max Depth = 6, Max Feat = 14, AUC PR 0.436
# Number Estimators= 86, Max Depth = 22, Max Feat = 4, AUC PR 0.184
# Number Estimators= 100, Max Depth = 36, Max Feat = 1, AUC PR 0.444
# Number Estimators= 100, Max Depth = 36, Max Feat = 1, AUC PR 0.343
# Number Estimators= 86, Max Depth = 53, Max Feat = 4, AUC PR 0.185
# Number Estimators= 7, Max Depth = 17, Max Feat = 15, AUC PR 0.213
# Number Estimators= 86, Max Depth = 22, Max Feat = 4, AUC PR 0.449
# Number Estimators= 86, Max Depth = 22, Max Feat = 4, AUC PR 0.347
# Number Estimators= 86, Max Depth = 53, Max Feat = 4, AUC PR 0.451
# Number Estimators= 86, Max Depth = 53, Max Feat = 4, AUC PR 0.348
# Number Estimators= 103, Max Depth = 16, Max Feat = 15, AUC PR 0.183
# Number Estimators= 7, Max Depth = 17, Max Feat = 26, AUC PR 0.454
# Number Estimators= 52, Max Depth = 1, Max Feat = 17, AUC PR 0.478
# Number Estimators= 7, Max Depth = 17, Max Feat = 26, AUC PR 0.358
# Number Estimators= 45, Max Depth = 15, Max Feat = 14, AUC PR 0.187
# Number Estimators= 77, Max Depth = 35, Max Feat = 7, AUC PR 0.179
# Number Estimators= 5, Max Depth = 21, Max Feat = 22, AUC PR 0.203
# Number Estimators= 125, Max Depth = 7, Max Feat = 7, AUC PR 0.191
# Number Estimators= 21, Max Depth = 53, Max Feat = 19, AUC PR 0.190
# Number Estimators= 26, Max Depth = 28, Max Feat = 6, AUC PR 0.197
# Number Estimators= 82, Max Depth = 33, Max Feat = 1, AUC PR 0.181
# Number Estimators= 114, Max Depth = 31, Max Feat = 7, AUC PR 0.177
# Number Estimators= 109, Max Depth = 33, Max Feat = 2, AUC PR 0.171
# Number Estimators= 71, Max Depth = 58, Max Feat = 16, AUC PR 0.187
# Number Estimators= 103, Max Depth = 16, Max Feat = 28, AUC PR 0.440
# Number Estimators= 103, Max Depth = 16, Max Feat = 28, AUC PR 0.346
# Number Estimators= 52, Max Depth = 1, Max Feat = 15, AUC PR 0.638
# Number Estimators= 52, Max Depth = 1, Max Feat = 15, AUC PR 0.594
# Number Estimators= 41, Max Depth = 55, Max Feat = 15, AUC PR 0.188
# Number Estimators= 24, Max Depth = 35, Max Feat = 11, AUC PR 0.181
# Number Estimators= 100, Max Depth = 37, Max Feat = 6, AUC PR 0.176
# Number Estimators= 45, Max Depth = 15, Max Feat = 15, AUC PR 0.441
# Number Estimators= 45, Max Depth = 15, Max Feat = 15, AUC PR 0.344
# Number Estimators= 109, Max Depth = 52, Max Feat = 11, AUC PR 0.176
# Number Estimators= 77, Max Depth = 35, Max Feat = 17, AUC PR 0.433
# Number Estimators= 77, Max Depth = 35, Max Feat = 17, AUC PR 0.338
# Number Estimators= 5, Max Depth = 21, Max Feat = 14, AUC PR 0.482
# Number Estimators= 5, Max Depth = 21, Max Feat = 14, AUC PR 0.376
# Number Estimators= 104, Max Depth = 18, Max Feat = 17, AUC PR 0.184
# Number Estimators= 112, Max Depth = 46, Max Feat = 5, AUC PR 0.175
# Number Estimators= 85, Max Depth = 2, Max Feat = 18, AUC PR 0.409
# Number Estimators= 125, Max Depth = 7, Max Feat = 7, AUC PR 0.484
# Number Estimators= 30, Max Depth = 58, Max Feat = 3, AUC PR 0.185
# Number Estimators= 125, Max Depth = 7, Max Feat = 7, AUC PR 0.375
# Number Estimators= 47, Max Depth = 35, Max Feat = 15, AUC PR 0.183
# Number Estimators= 21, Max Depth = 53, Max Feat = 22, AUC PR 0.473
# Number Estimators= 21, Max Depth = 53, Max Feat = 22, AUC PR 0.358
# Number Estimators= 95, Max Depth = 3, Max Feat = 12, AUC PR 0.264
# Number Estimators= 26, Max Depth = 28, Max Feat = 7, AUC PR 0.460
# Number Estimators= 26, Max Depth = 28, Max Feat = 7, AUC PR 0.355
# Number Estimators= 13, Max Depth = 39, Max Feat = 12, AUC PR 0.209
# Number Estimators= 34, Max Depth = 37, Max Feat = 9, AUC PR 0.186
# Number Estimators= 91, Max Depth = 49, Max Feat = 5, AUC PR 0.175
# Number Estimators= 112, Max Depth = 37, Max Feat = 17, AUC PR 0.181
# Number Estimators= 82, Max Depth = 33, Max Feat = 25, AUC PR 0.441
# Number Estimators= 82, Max Depth = 33, Max Feat = 25, AUC PR 0.343
# Number Estimators= 86, Max Depth = 9, Max Feat = 17, AUC PR 0.187
# Number Estimators= 56, Max Depth = 11, Max Feat = 5, AUC PR 0.180
# Number Estimators= 114, Max Depth = 46, Max Feat = 1, AUC PR 0.179
# Number Estimators= 96, Max Depth = 49, Max Feat = 15, AUC PR 0.182
# Number Estimators= 114, Max Depth = 31, Max Feat = 19, AUC PR 0.340
# Number Estimators= 106, Max Depth = 24, Max Feat = 20, AUC PR 0.182
# Number Estimators= 114, Max Depth = 31, Max Feat = 19, AUC PR 0.432
# Number Estimators= 109, Max Depth = 33, Max Feat = 6, AUC PR 0.345
# Number Estimators= 109, Max Depth = 33, Max Feat = 6, AUC PR 0.442
# Number Estimators= 71, Max Depth = 58, Max Feat = 1, AUC PR 0.351
# Number Estimators= 71, Max Depth = 58, Max Feat = 1, AUC PR 0.442
# Number Estimators= 128, Max Depth = 28, Max Feat = 19, AUC PR 0.180
# Number Estimators= 41, Max Depth = 55, Max Feat = 7, AUC PR 0.348
# Number Estimators= 24, Max Depth = 35, Max Feat = 2, AUC PR 0.347
# Number Estimators= 41, Max Depth = 55, Max Feat = 7, AUC PR 0.446
# Number Estimators= 24, Max Depth = 35, Max Feat = 2, AUC PR 0.470
# Number Estimators= 99, Max Depth = 54, Max Feat = 16, AUC PR 0.181
# Number Estimators= 68, Max Depth = 12, Max Feat = 11, AUC PR 0.178
# Number Estimators= 6, Max Depth = 40, Max Feat = 6, AUC PR 0.213
# Number Estimators= 50, Max Depth = 6, Max Feat = 11, AUC PR 0.194
# Number Estimators= 100, Max Depth = 37, Max Feat = 16, AUC PR 0.352
# Number Estimators= 100, Max Depth = 37, Max Feat = 16, AUC PR 0.433
# Number Estimators= 96, Max Depth = 43, Max Feat = 12, AUC PR 0.178
# Number Estimators= 59, Max Depth = 55, Max Feat = 14, AUC PR 0.183
# Number Estimators= 109, Max Depth = 52, Max Feat = 15, AUC PR 0.345
# Number Estimators= 111, Max Depth = 53, Max Feat = 19, AUC PR 0.181
# Number Estimators= 109, Max Depth = 52, Max Feat = 15, AUC PR 0.443
# Number Estimators= 47, Max Depth = 12, Max Feat = 16, AUC PR 0.183
# Number Estimators= 43, Max Depth = 9, Max Feat = 12, AUC PR 0.181
# Number Estimators= 10, Max Depth = 47, Max Feat = 4, AUC PR 0.207
# Number Estimators= 104, Max Depth = 18, Max Feat = 11, AUC PR 0.340
# Number Estimators= 104, Max Depth = 18, Max Feat = 11, AUC PR 0.436
# Number Estimators= 105, Max Depth = 21, Max Feat = 20, AUC PR 0.180
# Number Estimators= 104, Max Depth = 3, Max Feat = 6, AUC PR 0.295
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 50, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.2}
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_50_sliding_False_expvar_90_ratio_0.8_shuffle_True
# Loading Data from File..done
# Doing cutoff
# (2087, 29) (2087,) (521, 29) (521,)
# Number Estimators= 112, Max Depth = 46, Max Feat = 6, AUC PR 0.343
# Number Estimators= 112, Max Depth = 46, Max Feat = 6, AUC PR 0.442
# Number Estimators= 85, Max Depth = 2, Max Feat = 11, AUC PR 0.566
# Number Estimators= 85, Max Depth = 2, Max Feat = 11, AUC PR 0.642
# Number Estimators= 30, Max Depth = 58, Max Feat = 28, AUC PR 0.354
# Number Estimators= 30, Max Depth = 58, Max Feat = 28, AUC PR 0.442
# Number Estimators= 47, Max Depth = 35, Max Feat = 17, AUC PR 0.338
# Number Estimators= 47, Max Depth = 35, Max Feat = 17, AUC PR 0.432
# Number Estimators= 95, Max Depth = 3, Max Feat = 27, AUC PR 0.468
# Number Estimators= 95, Max Depth = 3, Max Feat = 27, AUC PR 0.583
# Number Estimators= 13, Max Depth = 39, Max Feat = 25, AUC PR 0.351
# Number Estimators= 119, Max Depth = 37, Max Feat = 27, AUC PR 0.250
# Number Estimators= 13, Max Depth = 39, Max Feat = 25, AUC PR 0.453
# Number Estimators= 34, Max Depth = 37, Max Feat = 23, AUC PR 0.343
# Number Estimators= 34, Max Depth = 37, Max Feat = 23, AUC PR 0.425
# Number Estimators= 91, Max Depth = 49, Max Feat = 5, AUC PR 0.362
# Number Estimators= 91, Max Depth = 49, Max Feat = 5, AUC PR 0.468
# Number Estimators= 91, Max Depth = 34, Max Feat = 21, AUC PR 0.248
# Number Estimators= 54, Max Depth = 21, Max Feat = 22, AUC PR 0.249
# Number Estimators= 45, Max Depth = 57, Max Feat = 3, AUC PR 0.260
# Number Estimators= 65, Max Depth = 44, Max Feat = 13, AUC PR 0.250
# Number Estimators= 112, Max Depth = 37, Max Feat = 28, AUC PR 0.345
# Number Estimators= 7, Max Depth = 56, Max Feat = 12, AUC PR 0.295
# Number Estimators= 112, Max Depth = 37, Max Feat = 28, AUC PR 0.435
# Number Estimators= 86, Max Depth = 9, Max Feat = 25, AUC PR 0.359
# Number Estimators= 125, Max Depth = 30, Max Feat = 15, AUC PR 0.254
# Number Estimators= 86, Max Depth = 9, Max Feat = 25, AUC PR 0.446
# Number Estimators= 34, Max Depth = 34, Max Feat = 15, AUC PR 0.258
# Number Estimators= 56, Max Depth = 11, Max Feat = 18, AUC PR 0.345
# Number Estimators= 56, Max Depth = 11, Max Feat = 18, AUC PR 0.450
# Number Estimators= 114, Max Depth = 46, Max Feat = 3, AUC PR 0.352
# Number Estimators= 88, Max Depth = 14, Max Feat = 7, AUC PR 0.250
# Number Estimators= 30, Max Depth = 44, Max Feat = 3, AUC PR 0.266
# Number Estimators= 114, Max Depth = 46, Max Feat = 3, AUC PR 0.451
# Number Estimators= 96, Max Depth = 49, Max Feat = 15, AUC PR 0.344
# Number Estimators= 96, Max Depth = 49, Max Feat = 15, AUC PR 0.449
# Number Estimators= 83, Max Depth = 15, Max Feat = 27, AUC PR 0.254
# Number Estimators= 106, Max Depth = 24, Max Feat = 12, AUC PR 0.349
# Number Estimators= 106, Max Depth = 24, Max Feat = 12, AUC PR 0.432
# Number Estimators= 108, Max Depth = 4, Max Feat = 25, AUC PR 0.339
# Number Estimators= 32, Max Depth = 44, Max Feat = 1, AUC PR 0.269
# Number Estimators= 14, Max Depth = 16, Max Feat = 1, AUC PR 0.304
# Number Estimators= 6, Max Depth = 31, Max Feat = 25, AUC PR 0.316
# Number Estimators= 78, Max Depth = 4, Max Feat = 5, AUC PR 0.350
# Number Estimators= 77, Max Depth = 56, Max Feat = 44, AUC PR 0.341
# Number Estimators= 112, Max Depth = 18, Max Feat = 7, AUC PR 0.253
# Number Estimators= 20, Max Depth = 14, Max Feat = 24, AUC PR 0.264
# Number Estimators= 128, Max Depth = 28, Max Feat = 23, AUC PR 0.340
# Number Estimators= 128, Max Depth = 28, Max Feat = 23, AUC PR 0.420
# Number Estimators= 77, Max Depth = 56, Max Feat = 44, AUC PR 0.296
# Number Estimators= 96, Max Depth = 52, Max Feat = 13, AUC PR 0.249
# Number Estimators= 99, Max Depth = 54, Max Feat = 12, AUC PR 0.351
# Number Estimators= 99, Max Depth = 54, Max Feat = 12, AUC PR 0.431
# Number Estimators= 68, Max Depth = 12, Max Feat = 9, AUC PR 0.353
# Number Estimators= 6, Max Depth = 40, Max Feat = 5, AUC PR 0.396
# Number Estimators= 68, Max Depth = 12, Max Feat = 9, AUC PR 0.435
# Number Estimators= 6, Max Depth = 40, Max Feat = 5, AUC PR 0.484
# Number Estimators= 50, Max Depth = 6, Max Feat = 17, AUC PR 0.373
# Number Estimators= 50, Max Depth = 6, Max Feat = 17, AUC PR 0.473
# Number Estimators= 77, Max Depth = 56, Max Feat = 44, AUC PR 0.236
# Number Estimators= 114, Max Depth = 58, Max Feat = 22, AUC PR 0.246
# Number Estimators= 96, Max Depth = 43, Max Feat = 17, AUC PR 0.339
# Number Estimators= 66, Max Depth = 19, Max Feat = 8, AUC PR 0.252
# Number Estimators= 96, Max Depth = 43, Max Feat = 17, AUC PR 0.434
# Number Estimators= 59, Max Depth = 55, Max Feat = 5, AUC PR 0.363
# Number Estimators= 111, Max Depth = 53, Max Feat = 1, AUC PR 0.342
# Number Estimators= 59, Max Depth = 55, Max Feat = 5, AUC PR 0.485
# Number Estimators= 111, Max Depth = 53, Max Feat = 1, AUC PR 0.442
# Number Estimators= 47, Max Depth = 12, Max Feat = 15, AUC PR 0.350
# Number Estimators= 47, Max Depth = 12, Max Feat = 15, AUC PR 0.440
# Number Estimators= 103, Max Depth = 56, Max Feat = 15, AUC PR 0.254
# Number Estimators= 43, Max Depth = 9, Max Feat = 20, AUC PR 0.345
# Number Estimators= 10, Max Depth = 47, Max Feat = 19, AUC PR 0.350
# Number Estimators= 43, Max Depth = 9, Max Feat = 20, AUC PR 0.455
# Number Estimators= 10, Max Depth = 47, Max Feat = 19, AUC PR 0.449
# Number Estimators= 54, Max Depth = 32, Max Feat = 23, AUC PR 0.261
# Number Estimators= 77, Max Depth = 56, Max Feat = 44, AUC PR 0.195
# Number Estimators= 105, Max Depth = 21, Max Feat = 24, AUC PR 0.354
# Number Estimators= 105, Max Depth = 21, Max Feat = 24, AUC PR 0.451
# Number Estimators= 104, Max Depth = 3, Max Feat = 16, AUC PR 0.496
# {'patient': 'cb46fd46', 'days': [3, 4, 5, 6, 7], 'wsize': 50, 'sliding': False, 'expvar': 90, 'ratio': 0.8, 'shuffle': True, 'cutoff': 0.3}
# /home/emil/OpenMindv2/data/postprocessing/patient_cb46fd46_days_[3, 4, 5, 6, 7]_wsize_50_sliding_False_expvar_90_ratio_0.8_shuffle_True
# Loading Data from File..done
# Doing cutoff
# (2087, 29) (2087,) (521, 29) (521,)
# Number Estimators= 15, Max Depth = 1, Max Feat = 22, AUC PR 0.368
# Number Estimators= 96, Max Depth = 50, Max Feat = 24, AUC PR 0.247
# Number Estimators= 104, Max Depth = 3, Max Feat = 16, AUC PR 0.591
# Number Estimators= 42, Max Depth = 30, Max Feat = 22, AUC PR 0.180
# Number Estimators= 84, Max Depth = 53, Max Feat = 11, AUC PR 0.256
# Number Estimators= 84, Max Depth = 16, Max Feat = 6, AUC PR 0.265
# Number Estimators= 16, Max Depth = 58, Max Feat = 26, AUC PR 0.292
# Number Estimators= 47, Max Depth = 14, Max Feat = 24, AUC PR 0.165
# Number Estimators= 15, Max Depth = 44, Max Feat = 7, AUC PR 0.285
# Number Estimators= 57, Max Depth = 33, Max Feat = 8, AUC PR 0.249
# Number Estimators= 34, Max Depth = 10, Max Feat = 12, AUC PR 0.262
# Number Estimators= 48, Max Depth = 42, Max Feat = 21, AUC PR 0.177
# Number Estimators= 50, Max Depth = 58, Max Feat = 22, AUC PR 0.177
# Number Estimators= 116, Max Depth = 13, Max Feat = 24, AUC PR 0.250
# Number Estimators= 90, Max Depth = 41, Max Feat = 5, AUC PR 0.260
# Number Estimators= 87, Max Depth = 59, Max Feat = 23, AUC PR 0.173
# Number Estimators= 88, Max Depth = 2, Max Feat = 27, AUC PR 0.444
# Number Estimators= 52, Max Depth = 47, Max Feat = 19, AUC PR 0.180
# Number Estimators= 80, Max Depth = 56, Max Feat = 24, AUC PR 0.167
# Number Estimators= 109, Max Depth = 31, Max Feat = 27, AUC PR 0.250
# Number Estimators= 84, Max Depth = 37, Max Feat = 5, AUC PR 0.258
# Number Estimators= 72, Max Depth = 51, Max Feat = 21, AUC PR 0.182
# Number Estimators= 33, Max Depth = 32, Max Feat = 28, AUC PR 0.271
# Number Estimators= 88, Max Depth = 11, Max Feat = 20, AUC PR 0.172
# Number Estimators= 123, Max Depth = 51, Max Feat = 28, AUC PR 0.254
# Number Estimators= 106, Max Depth = 22, Max Feat = 27, AUC PR 0.170
# Number Estimators= 88, Max Depth = 25, Max Feat = 13, AUC PR 0.250
# Number Estimators= 88, Max Depth = 53, Max Feat = 3, AUC PR 0.257
# Number Estimators= 5, Max Depth = 54, Max Feat = 8, AUC PR 0.298
# Number Estimators= 119, Max Depth = 37, Max Feat = 21, AUC PR 0.173
# Number Estimators= 98, Max Depth = 54, Max Feat = 23, AUC PR 0.258
# Number Estimators= 18, Max Depth = 24, Max Feat = 6, AUC PR 0.264
# Number Estimators= 91, Max Depth = 34, Max Feat = 22, AUC PR 0.174
# Number Estimators= 54, Max Depth = 21, Max Feat = 3, AUC PR 0.167
# Number Estimators= 110, Max Depth = 21, Max Feat = 21, AUC PR 0.245
# Number Estimators= 45, Max Depth = 57, Max Feat = 13, AUC PR 0.169
# Number Estimators= 77, Max Depth = 44, Max Feat = 28, AUC PR 0.341
# Number Estimators= 65, Max Depth = 44, Max Feat = 12, AUC PR 0.169
# Number Estimators= 7, Max Depth = 56, Max Feat = 15, AUC PR 0.199
# Number Estimators= 126, Max Depth = 54, Max Feat = 10, AUC PR 0.253
# Number Estimators= 77, Max Depth = 44, Max Feat = 28, AUC PR 0.300
# Number Estimators= 125, Max Depth = 30, Max Feat = 15, AUC PR 0.170
# Number Estimators= 34, Max Depth = 34, Max Feat = 7, AUC PR 0.175
# Number Estimators= 88, Max Depth = 14, Max Feat = 3, AUC PR 0.163
# Number Estimators= 127, Max Depth = 55, Max Feat = 22, AUC PR 0.246
# Number Estimators= 30, Max Depth = 44, Max Feat = 27, AUC PR 0.182
# Number Estimators= 115, Max Depth = 19, Max Feat = 10, AUC PR 0.251
# Number Estimators= 83, Max Depth = 15, Max Feat = 25, AUC PR 0.170
# Number Estimators= 124, Max Depth = 31, Max Feat = 10, AUC PR 0.253
# Number Estimators= 108, Max Depth = 4, Max Feat = 1, AUC PR 0.241
# Number Estimators= 32, Max Depth = 44, Max Feat = 1, AUC PR 0.177
# Number Estimators= 77, Max Depth = 44, Max Feat = 28, AUC PR 0.231
# Number Estimators= 14, Max Depth = 16, Max Feat = 25, AUC PR 0.185
# Number Estimators= 6, Max Depth = 31, Max Feat = 5, AUC PR 0.202
# Number Estimators= 119, Max Depth = 24, Max Feat = 3, AUC PR 0.258
# Number Estimators= 15, Max Depth = 53, Max Feat = 16, AUC PR 0.276
# Number Estimators= 78, Max Depth = 4, Max Feat = 7, AUC PR 0.244
# Number Estimators= 26, Max Depth = 20, Max Feat = 23, AUC PR 0.270
# Number Estimators= 112, Max Depth = 18, Max Feat = 24, AUC PR 0.163
# Number Estimators= 20, Max Depth = 14, Max Feat = 13, AUC PR 0.175
# Number Estimators= 96, Max Depth = 52, Max Feat = 22, AUC PR 0.174
# Number Estimators= 77, Max Depth = 44, Max Feat = 28, AUC PR 0.195
# Number Estimators= 114, Max Depth = 58, Max Feat = 8, AUC PR 0.167
# Number Estimators= 66, Max Depth = 19, Max Feat = 15, AUC PR 0.169
# Number Estimators= 103, Max Depth = 56, Max Feat = 23, AUC PR 0.170
# Number Estimators= 54, Max Depth = 32, Max Feat = 24, AUC PR 0.169
# Number Estimators= 96, Max Depth = 50, Max Feat = 11, AUC PR 0.174
# Number Estimators= 84, Max Depth = 53, Max Feat = 6, AUC PR 0.175
# Number Estimators= 84, Max Depth = 16, Max Feat = 26, AUC PR 0.169
# Number Estimators= 16, Max Depth = 58, Max Feat = 7, AUC PR 0.195
# Number Estimators= 15, Max Depth = 44, Max Feat = 8, AUC PR 0.202
# Number Estimators= 57, Max Depth = 33, Max Feat = 12, AUC PR 0.173
# Number Estimators= 34, Max Depth = 10, Max Feat = 24, AUC PR 0.183
# Number Estimators= 116, Max Depth = 13, Max Feat = 5, AUC PR 0.164
# Number Estimators= 90, Max Depth = 41, Max Feat = 27, AUC PR 0.172
# Number Estimators= 88, Max Depth = 2, Max Feat = 27, AUC PR 0.310
# Number Estimators= 109, Max Depth = 31, Max Feat = 5, AUC PR 0.174
# Number Estimators= 84, Max Depth = 37, Max Feat = 28, AUC PR 0.172
# Number Estimators= 33, Max Depth = 32, Max Feat = 28, AUC PR 0.180
# Number Estimators= 123, Max Depth = 51, Max Feat = 13, AUC PR 0.163
# Number Estimators= 88, Max Depth = 25, Max Feat = 3, AUC PR 0.166
# Number Estimators= 88, Max Depth = 53, Max Feat = 8, AUC PR 0.171
# Number Estimators= 87, Max Depth = 14, Max Feat = 47, AUC PR 0.343
# Number Estimators= 87, Max Depth = 14, Max Feat = 47, AUC PR 0.302
# Number Estimators= 87, Max Depth = 14, Max Feat = 47, AUC PR 0.237
# Number Estimators= 87, Max Depth = 14, Max Feat = 47, AUC PR 0.191
# Number Estimators= 121, Max Depth = 7, Max Feat = 38, AUC PR 0.376
# Number Estimators= 121, Max Depth = 7, Max Feat = 38, AUC PR 0.263
# Number Estimators= 121, Max Depth = 7, Max Feat = 38, AUC PR 0.327
# Number Estimators= 121, Max Depth = 7, Max Feat = 38, AUC PR 0.218
# Number Estimators= 93, Max Depth = 31, Max Feat = 61, AUC PR 0.228
# Number Estimators= 93, Max Depth = 31, Max Feat = 61, AUC PR 0.336
# Number Estimators= 87, Max Depth = 52, Max Feat = 13, AUC PR 0.233
# Number Estimators= 87, Max Depth = 52, Max Feat = 13, AUC PR 0.344
# Number Estimators= 93, Max Depth = 31, Max Feat = 61, AUC PR 0.294
# Number Estimators= 93, Max Depth = 31, Max Feat = 61, AUC PR 0.195
# Number Estimators= 87, Max Depth = 52, Max Feat = 13, AUC PR 0.300
# Number Estimators= 87, Max Depth = 52, Max Feat = 13, AUC PR 0.194
# Number Estimators= 126, Max Depth = 16, Max Feat = 57, AUC PR 0.234
# Number Estimators= 126, Max Depth = 16, Max Feat = 57, AUC PR 0.339
# Number Estimators= 40, Max Depth = 23, Max Feat = 43, AUC PR 0.231
# Number Estimators= 126, Max Depth = 16, Max Feat = 57, AUC PR 0.298
# Number Estimators= 40, Max Depth = 23, Max Feat = 43, AUC PR 0.348
# Number Estimators= 126, Max Depth = 16, Max Feat = 57, AUC PR 0.192
# Number Estimators= 40, Max Depth = 23, Max Feat = 43, AUC PR 0.293
# Number Estimators= 40, Max Depth = 23, Max Feat = 43, AUC PR 0.197
# Number Estimators= 117, Max Depth = 52, Max Feat = 34, AUC PR 0.231
# Number Estimators= 117, Max Depth = 52, Max Feat = 34, AUC PR 0.337
# Number Estimators= 41, Max Depth = 54, Max Feat = 44, AUC PR 0.239
# Number Estimators= 117, Max Depth = 52, Max Feat = 34, AUC PR 0.294
# Number Estimators= 41, Max Depth = 54, Max Feat = 44, AUC PR 0.343
# Number Estimators= 41, Max Depth = 54, Max Feat = 44, AUC PR 0.301
# Number Estimators= 117, Max Depth = 52, Max Feat = 34, AUC PR 0.195
# Number Estimators= 95, Max Depth = 31, Max Feat = 27, AUC PR 0.232
# Number Estimators= 95, Max Depth = 31, Max Feat = 27, AUC PR 0.333
# Number Estimators= 109, Max Depth = 51, Max Feat = 9, AUC PR 0.234
# Number Estimators= 109, Max Depth = 51, Max Feat = 9, AUC PR 0.347
# Number Estimators= 41, Max Depth = 54, Max Feat = 44, AUC PR 0.197
# Number Estimators= 95, Max Depth = 31, Max Feat = 27, AUC PR 0.297
# Number Estimators= 84, Max Depth = 38, Max Feat = 6, AUC PR 0.240
# Number Estimators= 84, Max Depth = 38, Max Feat = 6, AUC PR 0.350
# Number Estimators= 22, Max Depth = 48, Max Feat = 25, AUC PR 0.242
# Number Estimators= 22, Max Depth = 48, Max Feat = 25, AUC PR 0.346
# Number Estimators= 109, Max Depth = 51, Max Feat = 9, AUC PR 0.295
# Number Estimators= 84, Max Depth = 38, Max Feat = 6, AUC PR 0.303
# Number Estimators= 22, Max Depth = 48, Max Feat = 25, AUC PR 0.303
# Number Estimators= 95, Max Depth = 31, Max Feat = 27, AUC PR 0.194
# Number Estimators= 41, Max Depth = 23, Max Feat = 36, AUC PR 0.229
# Number Estimators= 41, Max Depth = 23, Max Feat = 36, AUC PR 0.338
# Number Estimators= 11, Max Depth = 31, Max Feat = 47, AUC PR 0.251
# Number Estimators= 41, Max Depth = 23, Max Feat = 36, AUC PR 0.300
# Number Estimators= 11, Max Depth = 31, Max Feat = 47, AUC PR 0.351
# Number Estimators= 109, Max Depth = 51, Max Feat = 9, AUC PR 0.196
# Number Estimators= 11, Max Depth = 31, Max Feat = 47, AUC PR 0.305
# Number Estimators= 84, Max Depth = 38, Max Feat = 6, AUC PR 0.195
# Number Estimators= 22, Max Depth = 48, Max Feat = 25, AUC PR 0.198
# Number Estimators= 41, Max Depth = 23, Max Feat = 36, AUC PR 0.195
# Number Estimators= 11, Max Depth = 31, Max Feat = 47, AUC PR 0.205
# Number Estimators= 117, Max Depth = 20, Max Feat = 56, AUC PR 0.231
# Number Estimators= 117, Max Depth = 20, Max Feat = 56, AUC PR 0.339
# Number Estimators= 117, Max Depth = 20, Max Feat = 56, AUC PR 0.296
# Number Estimators= 72, Max Depth = 34, Max Feat = 66, AUC PR 0.342
# Number Estimators= 72, Max Depth = 34, Max Feat = 66, AUC PR 0.234
# Number Estimators= 117, Max Depth = 20, Max Feat = 56, AUC PR 0.193
# Number Estimators= 72, Max Depth = 34, Max Feat = 66, AUC PR 0.294
# Number Estimators= 68, Max Depth = 59, Max Feat = 28, AUC PR 0.342
# Number Estimators= 68, Max Depth = 59, Max Feat = 28, AUC PR 0.231
# Number Estimators= 68, Max Depth = 59, Max Feat = 28, AUC PR 0.300
# Number Estimators= 72, Max Depth = 34, Max Feat = 66, AUC PR 0.190
# Number Estimators= 99, Max Depth = 11, Max Feat = 79, AUC PR 0.348
# Number Estimators= 99, Max Depth = 11, Max Feat = 79, AUC PR 0.244
# Number Estimators= 68, Max Depth = 59, Max Feat = 28, AUC PR 0.198
# Number Estimators= 99, Max Depth = 11, Max Feat = 79, AUC PR 0.307
# Number Estimators= 74, Max Depth = 21, Max Feat = 22, AUC PR 0.335
# Number Estimators= 74, Max Depth = 21, Max Feat = 22, AUC PR 0.231
# Number Estimators= 74, Max Depth = 21, Max Feat = 22, AUC PR 0.297
# Number Estimators= 60, Max Depth = 23, Max Feat = 59, AUC PR 0.341
# Number Estimators= 60, Max Depth = 23, Max Feat = 59, AUC PR 0.230
# Number Estimators= 60, Max Depth = 23, Max Feat = 59, AUC PR 0.295
# Number Estimators= 99, Max Depth = 11, Max Feat = 79, AUC PR 0.198
# Number Estimators= 85, Max Depth = 10, Max Feat = 31, AUC PR 0.353
# Number Estimators= 85, Max Depth = 10, Max Feat = 31, AUC PR 0.243
# Number Estimators= 74, Max Depth = 21, Max Feat = 22, AUC PR 0.194
# Number Estimators= 85, Max Depth = 10, Max Feat = 31, AUC PR 0.304
# Number Estimators= 125, Max Depth = 35, Max Feat = 31, AUC PR 0.334
# Number Estimators= 125, Max Depth = 35, Max Feat = 31, AUC PR 0.231
# Number Estimators= 60, Max Depth = 23, Max Feat = 59, AUC PR 0.196
# Number Estimators= 125, Max Depth = 35, Max Feat = 31, AUC PR 0.296
# Number Estimators= 54, Max Depth = 33, Max Feat = 46, AUC PR 0.345
# Number Estimators= 85, Max Depth = 10, Max Feat = 31, AUC PR 0.196
# Number Estimators= 54, Max Depth = 33, Max Feat = 46, AUC PR 0.235
# Number Estimators= 54, Max Depth = 33, Max Feat = 46, AUC PR 0.297
# Number Estimators= 55, Max Depth = 52, Max Feat = 74, AUC PR 0.343
# Number Estimators= 125, Max Depth = 35, Max Feat = 31, AUC PR 0.191
# Number Estimators= 55, Max Depth = 52, Max Feat = 74, AUC PR 0.235
# Number Estimators= 55, Max Depth = 52, Max Feat = 74, AUC PR 0.301
# Number Estimators= 76, Max Depth = 26, Max Feat = 40, AUC PR 0.340
# Number Estimators= 112, Max Depth = 1, Max Feat = 35, AUC PR 0.500
# Number Estimators= 54, Max Depth = 33, Max Feat = 46, AUC PR 0.195
# Number Estimators= 76, Max Depth = 26, Max Feat = 40, AUC PR 0.296
# Number Estimators= 76, Max Depth = 26, Max Feat = 40, AUC PR 0.231
# Number Estimators= 112, Max Depth = 1, Max Feat = 35, AUC PR 0.445
# Number Estimators= 112, Max Depth = 1, Max Feat = 35, AUC PR 0.365
# Number Estimators= 55, Max Depth = 52, Max Feat = 74, AUC PR 0.196
# Number Estimators= 118, Max Depth = 29, Max Feat = 63, AUC PR 0.337
# Number Estimators= 122, Max Depth = 2, Max Feat = 56, AUC PR 0.509
# Number Estimators= 76, Max Depth = 26, Max Feat = 40, AUC PR 0.188
# Number Estimators= 112, Max Depth = 1, Max Feat = 35, AUC PR 0.312
# Number Estimators= 118, Max Depth = 29, Max Feat = 63, AUC PR 0.295
# Number Estimators= 118, Max Depth = 29, Max Feat = 63, AUC PR 0.232
# Number Estimators= 23, Max Depth = 39, Max Feat = 87, AUC PR 0.347
# Number Estimators= 122, Max Depth = 2, Max Feat = 56, AUC PR 0.466
# Number Estimators= 122, Max Depth = 2, Max Feat = 56, AUC PR 0.374
# Number Estimators= 33, Max Depth = 54, Max Feat = 26, AUC PR 0.345
# Number Estimators= 39, Max Depth = 2, Max Feat = 16, AUC PR 0.475
# Number Estimators= 23, Max Depth = 39, Max Feat = 87, AUC PR 0.305
# Number Estimators= 31, Max Depth = 35, Max Feat = 56, AUC PR 0.348
# Number Estimators= 23, Max Depth = 39, Max Feat = 87, AUC PR 0.240
# Number Estimators= 33, Max Depth = 54, Max Feat = 26, AUC PR 0.301
# Number Estimators= 39, Max Depth = 2, Max Feat = 16, AUC PR 0.433
# Number Estimators= 31, Max Depth = 31, Max Feat = 41, AUC PR 0.344
# Number Estimators= 33, Max Depth = 54, Max Feat = 26, AUC PR 0.236
# Number Estimators= 39, Max Depth = 2, Max Feat = 16, AUC PR 0.346
# Number Estimators= 115, Max Depth = 2, Max Feat = 10, AUC PR 0.491
# Number Estimators= 31, Max Depth = 35, Max Feat = 56, AUC PR 0.304
# Number Estimators= 31, Max Depth = 35, Max Feat = 56, AUC PR 0.237
# Number Estimators= 54, Max Depth = 22, Max Feat = 38, AUC PR 0.338
# Number Estimators= 31, Max Depth = 31, Max Feat = 41, AUC PR 0.298
# Number Estimators= 115, Max Depth = 2, Max Feat = 10, AUC PR 0.438
# Number Estimators= 81, Max Depth = 2, Max Feat = 77, AUC PR 0.503
# Number Estimators= 118, Max Depth = 29, Max Feat = 63, AUC PR 0.186
# Number Estimators= 31, Max Depth = 31, Max Feat = 41, AUC PR 0.236
# Number Estimators= 115, Max Depth = 2, Max Feat = 10, AUC PR 0.349
# Number Estimators= 122, Max Depth = 2, Max Feat = 56, AUC PR 0.308
# Number Estimators= 54, Max Depth = 22, Max Feat = 38, AUC PR 0.293
# Number Estimators= 37, Max Depth = 26, Max Feat = 57, AUC PR 0.338
# Number Estimators= 54, Max Depth = 22, Max Feat = 38, AUC PR 0.234
# Number Estimators= 81, Max Depth = 2, Max Feat = 77, AUC PR 0.463
# Number Estimators= 81, Max Depth = 2, Max Feat = 77, AUC PR 0.358
# Number Estimators= 23, Max Depth = 39, Max Feat = 87, AUC PR 0.199
# Number Estimators= 37, Max Depth = 26, Max Feat = 57, AUC PR 0.298
# Number Estimators= 33, Max Depth = 54, Max Feat = 26, AUC PR 0.199
# Number Estimators= 39, Max Depth = 2, Max Feat = 16, AUC PR 0.286
# Number Estimators= 37, Max Depth = 26, Max Feat = 57, AUC PR 0.234
# Number Estimators= 31, Max Depth = 35, Max Feat = 56, AUC PR 0.196
# Number Estimators= 31, Max Depth = 31, Max Feat = 41, AUC PR 0.195
# Number Estimators= 115, Max Depth = 2, Max Feat = 10, AUC PR 0.288
# Number Estimators= 105, Max Depth = 17, Max Feat = 73, AUC PR 0.337
# Number Estimators= 10, Max Depth = 44, Max Feat = 57, AUC PR 0.358
# Number Estimators= 8, Max Depth = 50, Max Feat = 72, AUC PR 0.364
# Number Estimators= 54, Max Depth = 22, Max Feat = 38, AUC PR 0.197
# Number Estimators= 105, Max Depth = 17, Max Feat = 73, AUC PR 0.300
# Number Estimators= 81, Max Depth = 2, Max Feat = 77, AUC PR 0.299
# Number Estimators= 10, Max Depth = 44, Max Feat = 57, AUC PR 0.317
# Number Estimators= 74, Max Depth = 35, Max Feat = 32, AUC PR 0.343
# Number Estimators= 8, Max Depth = 50, Max Feat = 72, AUC PR 0.318
# Number Estimators= 105, Max Depth = 17, Max Feat = 73, AUC PR 0.233
# Number Estimators= 10, Max Depth = 44, Max Feat = 57, AUC PR 0.249
# Number Estimators= 81, Max Depth = 50, Max Feat = 18, AUC PR 0.338
# Number Estimators= 37, Max Depth = 26, Max Feat = 57, AUC PR 0.196
# Number Estimators= 8, Max Depth = 50, Max Feat = 72, AUC PR 0.254
# Number Estimators= 74, Max Depth = 35, Max Feat = 32, AUC PR 0.299
